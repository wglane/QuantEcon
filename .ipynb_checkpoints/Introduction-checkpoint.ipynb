# %% [markdown]
# # Plotting and For Loops

# %%
using Plots
n = 100
ϵ_vals = randn(n)
plot(ϵ_vals, color="blue")

# %% [markdown]
# ## Another Way

# %%
n = 100
ϵ_vals = Array{Float64}(n)
for i in 1:n
    ϵ_vals[i] = randn()
end
plot(ϵ_vals, color="blue")

# %% [markdown]
# ## Foreach-style loops

# %%
words = ["hello", "goodbye"]
for word in words
    println(word)
end
# Out:
# hello
# goodbye

# %% [markdown]
# ## While Loop + If Statement

# %%
n = 100
ϵ_vals = Array{Float64}(100)
i = 1
while true
    ϵ_vals[i] = randn()
    i += 1
    if i > n
        break
    end
end
plot(ϵ_vals, color="blue")

# %% [markdown]
# ## UDFs

# %%
function generate_data(n)
    vals = Array{Float64}(n)
    for i in 1:n
        vals[i] = randn()
    end
    return vals
end

plot(generate_data(100), color="red")

# %%
using Distributions

function plot_histogram(dist, n)
    vals = rand(dist, n)
    histogram(vals)
end

rv = BivariateNormal((3, 2))
plot_histogram(rv, 1000)
# Out:
# UndefVarError: BivariateNormal not defined
#
# Stacktrace:
#  [1] include_string(::String, ::String) at ./loading.jl:522
#  [2] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /Users/williamlane/.julia/v0.6/IJulia/src/execute_request.jl:193
#  [3] (::Compat.#inner#14{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at /Users/williamlane/.julia/v0.6/Compat/src/Compat.jl:332
#  [4] eventloop(::ZMQ.Socket) at /Users/williamlane/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [5] (::IJulia.##13#16)() at ./task.jl:335

# %% [markdown]
# # Exercises
#
# ## Exercise 1

# %%
function factorial2(n)
    if n <= 1
        return 1
    end
    ans = 1
    for i in 2:n
        ans *= i
    end
    return ans
end

println(factorial2(5))
# Out:
# 120

# %% [markdown]
# ## Exercise 2

# %%
function binomial_rv(n, p)
    count = 0
    for i in 1:n
        if rand() < p
            count += 1
        end
    end
    return count
end
    
binomial_rv(10, .5)
# Out:
# 7

# %% [markdown]
# ## Exercise 3

# %%
function approximate_pi(n_trials)
    count = 0
    for i in 1:n_trials
        x, y = rand() - 0.5, rand() - 0.5
        if (x*x) + (y*y) < .25
            count += 1
        end
    end
    return (4 / n_trials) * count
end

approximate_pi(99999)
# Out:
# 3.145911459114591

# %% [markdown]
# ## Exercise 4

# %%
function random_device()
    run = 0
    for i in 1:10
        if rand() < 0.5
            run += 1
            if run == 3
                return 1
            end
        else
            run = 0
        end
    end
    return 0
end

random_device()
# Out:
# 0

# %% [markdown]
# ## Exercise 5

# %%
function generate_correlated_series(T, α)
    vals = Array{Float64}(T+1)
    vals[1] = 0
    for i in 2:T+1
        vals[i] = α * vals[i-1] + randn()
    end
    return vals
end

plot(generate_correlated_series(200, 0.9), color="blue", label="series")

# %% [markdown]
# ## Exercise 6

# %%
vals = [generate_correlated_series(200, 0), generate_correlated_series(200, .8), generate_correlated_series(200, .98)];

plot(vals, label=["a", "b", "c"])
